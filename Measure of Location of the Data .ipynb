# %%
import pandas as pd

# %%
dataset=pd.read_csv('placement.csv')

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from quanqual import QUANQUAL
quan,qual=QUANQUAL.QuanQual(dataset)

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %% [markdown]
# # percentile  - numpy library is use fully numerical calculation

# %%
import numpy as np

# %%
np.percentile(dataset['ssc_p'],10) #10% of ssc_p mark
# Out:
# 52.0

# %%
np.percentile(dataset['ssc_p'],15) #  15% of ssc_p mark
# Out:
# 55.0

# %%
descriptive=pd.DataFrame(index=['Percentile:25%','Percentile:50%','Percentile:75%','Percentile:100%'],columns=quan)
for ColumnName in quan:
    descriptive[ColumnName]['Percentile:25%']=np.percentile(dataset[ColumnName],25)
    descriptive[ColumnName]['Percentile:50%']=np.percentile(dataset[ColumnName],50)
    descriptive[ColumnName]['Percentile:75%']=np.percentile(dataset[ColumnName],75)
    descriptive[ColumnName]['Percentile:100%']=np.percentile(dataset[ColumnName],100)
# Out:
# C:\Users\Pravin\AppData\Local\Temp\ipykernel_18384\1656725449.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[ColumnName]['Percentile:25%']=np.percentile(dataset[ColumnName],25)
# ...

# %%
descriptive
# Out:
#                  sl_no ssc_p hsc_p degree_p etest_p   mba_p salary
# Percentile:25%    54.5  60.6  60.9     61.0    60.0  57.945    NaN
# Percentile:50%   108.0  67.0  65.0     66.0    71.0    62.0    NaN
# Percentile:75%   161.5  75.7  73.0     72.0    83.5  66.255    NaN
# Percentile:100%  215.0  89.4  97.7     91.0    98.0   77.89    NaN

# %% [markdown]
# # Alternate Way percentile calculation in inbuilt function

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
alterwave=pd.DataFrame(index=['Q1:25%','Q2:50%','Q3:75%','Q4:100%'],columns=quan)
for ColumnName in quan:
    alterwave[ColumnName]['Q1:25%']=dataset.describe()[ColumnName]['25%']
    alterwave[ColumnName]['Q2:50%']=dataset.describe()[ColumnName]['50%']
    alterwave[ColumnName]['Q3:75%']=dataset.describe()[ColumnName]['75%']
    alterwave[ColumnName]['Q4:100%']=dataset.describe()[ColumnName]['max']
# Out:
# C:\Users\Pravin\AppData\Local\Temp\ipykernel_18384\3265855244.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   alterwave[ColumnName]['Q1:25%']=dataset.describe()[ColumnName]['25%']
# ...

# %%
alterwave
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p   mba_p    salary
# Q1:25%    54.5  60.6  60.9     61.0    60.0  57.945  240000.0
# Q2:50%   108.0  67.0  65.0     66.0    71.0    62.0  265000.0
# Q3:75%   161.5  75.7  73.0     72.0    83.5  66.255  300000.0
# Q4:100%  215.0  89.4  97.7     91.0    98.0   77.89  940000.0
